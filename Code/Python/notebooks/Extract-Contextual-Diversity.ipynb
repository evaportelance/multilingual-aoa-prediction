# %%
import pickle
import csv
import os
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
def open_pkl(dir):
    with open(dir, 'rb') as file:
        return pickle.load(file)
    
def open_word_list_csv(csv_path):
    with open(csv_path, newline='\n') as csv_file:
        word_list = []
        csv_contents = csv.DictReader(csv_file, delimiter=',', quotechar='|')
        for row in csv_contents:
            word_list.append(row)
        return word_list

# %%
data_file = "../../../Data/model_datasets/spa/train_vocab_size_5000.pkl"
vocab_file = "../../../Data/model_datasets/spa/encoding_dictionary_vocab_size_5000.pkl"
word_list_file = "../../../Analyses/data/surprisal-and-frequency/lstm-surprisals/Spanish (Mexican)/all_child_directed_data_spanish_(mexican)_singleword_average_surprisal_perplexity_run0.csv"

# %%
data = open_pkl(data_file)
vocab = open_pkl(vocab_file)

# %%
word_list = open_word_list_csv(word_list_file)

# %%
def cooccurrence_matrix(sentences, window_size):
    d = defaultdict(int)
    vocab = set()
    for s in sentences:
        for i in range(len(s)):
            if not s[i] == 0:
                token = s[i]
                vocab.add(token)  # add to vocab
                next_token = s[i+1 : i+1+window_size]
                for t in next_token:
                    key = tuple( sorted([t, token]) )
                    d[key] += 1
    # formulate the dictionary into dataframe
    vocab = sorted(vocab) # sort vocab
    df = pd.DataFrame(data=np.zeros((len(vocab), len(vocab)), dtype=np.int16),
                      index=vocab,
                      columns=vocab)
    for key, value in d.items():
        df.at[key[0], key[1]] = value
        df.at[key[1], key[0]] = value
    return df

# %%
matrix = cooccurrence_matrix(data, 5)

# %%
def get_contextual_diversity(word_list, vocab, matrix):
    def get_word_score(word):
        index = vocab[word]
        try:
            row = matrix[index]
            cd = 0
            for i in row:
                if not i == 0:
                    cd+=1
        except:
            cd = 'NA'
        return cd
    cd_word_list = []
    for item in word_list:
        word = item['word_clean']
        language = item['language']
        cd_score = get_word_score(word)
        cd_word_list.append({'language': language, 'word_clean':word, 'cd_score':cd_score})
    return cd_word_list

# %%
cd_word_list = get_contextual_diversity(word_list, vocab, matrix)

# %%
cd_word_list
# Out:
# [{'language': 'Spanish (Mexican)', 'word_clean': 'un', 'cd_score': 1591},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'una', 'cd_score': 1186},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'unas', 'cd_score': 152},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'unos', 'cd_score': 215},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'mucho', 'cd_score': 404},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'otro', 'cd_score': 562},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'avión', 'cd_score': 15},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'todo', 'cd_score': 494},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ya', 'cd_score': 1114},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'también', 'cd_score': 744},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'enojado', 'cd_score': 7},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'animal', 'cd_score': 53},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'manzana', 'cd_score': 21},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'brazos', 'cd_score': 61},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'brazo', 'cd_score': 23},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'atrás', 'cd_score': 109},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'malo', 'cd_score': 111},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'pelota', 'cd_score': 176},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'globo', 'cd_score': 61},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'plátano', 'cd_score': 22},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'baño', 'cd_score': 99},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'estar', 'cd_score': 240},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ser', 'cd_score': 239},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'playa', 'cd_score': 68},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'oso', 'cd_score': 82},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'cama', 'cd_score': 403},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'abeja', 'cd_score': 10},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ombligo', 'cd_score': 8},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'babero', 'cd_score': 5},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'bicicleta', 'cd_score': 40},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'grande', 'cd_score': 329},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'pájaro', 'cd_score': 32},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'morder', 'cd_score': 15},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'soplar', 'cd_score': 46},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'azul', 'cd_score': 93},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'barco', 'cd_score': 255},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'libro', 'cd_score': 89},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'botas', 'cd_score': 79},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'botella', 'cd_score': 13},
#  {'language': 'Spanish (Mexican)', 'word_clean': 

#  {'language': 'Spanish (Mexican)', 'word_clean': 'escaleras', 'cd_score': 68},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'estrella', 'cd_score': 23},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'parar', 'cd_score': 23},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tienda', 'cd_score': 25},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'estufa', 'cd_score': 25},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'calle', 'cd_score': 201},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'sol', 'cd_score': 105},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'columpio', 'cd_score': 217},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'mesa', 'cd_score': 323},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'llevar', 'cd_score': 159},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tomar', 'cd_score': 103},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'sacar', 'cd_score': 159},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'osito', 'cd_score': 77},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'teléfono', 'cd_score': 95},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'aquel', 'cd_score': 22},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'aquella', 'cd_score': 45},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'esa', 'cd_score': 504},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ese', 'cd_score': 682},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'eso', 'cd_score': 853},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'el', 'cd_score': 2214},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'la', 'cd_score': 2544},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'las', 'cd_score': 1152},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'los', 'cd_score': 1472},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'les', 'cd_score': 633},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ahí', 'cd_score': 964},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'éstas', 'cd_score': 111},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'éstos', 'cd_score': 298},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ellas', 'cd_score': 36},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ellos', 'cd_score': 126},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'sed', 'cd_score': 21},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ésta', 'cd_score': 479},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'éste', 'cd_score': 683},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'esto', 'cd_score': 682},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'esas', 'cd_score': 168},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'esos', 'cd_score': 280},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tirar', 'cd_score': 131},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tigre', 'cd_score': 13},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'medias', 'cd_score': 43},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'cansado', 'cd_score': 79},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'lengua', 'cd_score': 27},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'dientes', 'cd_score': 43},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tortilla', 'cd_score': 45},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tocar', 'cd_score': 52},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'toalla', 'cd_score': 37},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'juguete', 'cd_score': 94},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tren', 'cd_score': 115},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'basura', 'cd_score': 11},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'árbol', 'cd_score': 137},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'camión', 'cd_score': 37},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'panza', 'cd_score': 12},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'apagar', 'cd_score': 31},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'prender', 'cd_score': 'NA'},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tortuga', 'cd_score': 34},
#  {'language': 'Spanish (Mexican)',
#   'word_clean': 'televisión',
#   'cd_score': 111},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'feo', 'cd_score': 58},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'arriba', 'cd_score': 210},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'esperar', 'cd_score': 41},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'caminar', 'cd_score': 4},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'querer', 'cd_score': 28},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'lavar', 'cd_score': 75},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'reloj', 'cd_score': 62},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'agua', 'cd_score': 286},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'mojar', 'cd_score': 28},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'qué', 'cd_score': 1878},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'qué', 'cd_score': 1878},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'dónde', 'cd_score': 860},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'cuál', 'cd_score': 279},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'quién', 'cd_score': 765},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ventana', 'cd_score': 158},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'lobo', 'cd_score': 184},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'trabajar', 'cd_score': 90},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'escribir', 'cd_score': 50},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'amarillo', 'cd_score': 100},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'te', 'cd_score': 1721},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tú', 'cd_score': 1047},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tuya', 'cd_score': 96},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tuyas', 'cd_score': 20},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tuyo', 'cd_score': 97},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'tuyos', 'cd_score': 23},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'cierre', 'cd_score': 22},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'bomba', 'cd_score': 39},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'coche', 'cd_score': 432},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'garaje', 'cd_score': 263},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'nieve', 'cd_score': 252},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'chupete', 'cd_score': 70},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'piscina', 'cd_score': 73},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'susto', 'cd_score': 90},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'ducha', 'cd_score': 23},
#  {'language': 'Spanish (Mexican)', 'word_clean': 'allí', 'cd_score': 152}]

# %%
def save_cd_csv(cd_word_list, experiment_dir):
    language = cd_word_list[0]['language']
    file_name = language + '_contextual_diversity_scores5000.csv'
    with open(os.path.join(experiment_dir, file_name), mode='w') as csv_file:
        writer = csv.writer(csv_file, delimiter=',')
        writer.writerow(['language', 'word_clean', 'cd_score'])
        for word in cd_word_list:
            writer.writerow([word['language'], word['word_clean'], str(word['cd_score'])])

# %%
save_cd_csv(cd_word_list, "./contextual-diversity")
